# %% [markdown]
# # Exploratory Data Analysis (EDA) - Alzheimer's Disease MRI Images
# This notebook demonstrates loading public MRI datasets (ADNI, OASIS, Kaggle), analyzing class distributions, checking image dimensions, and visualizing sample MRI slices across disease stages.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from ml.datasets.loader import MRIDatasetLoader
from ml.preprocessing.validation import DatasetValidator

# Set dataset directories
data_dirs = ['../data/raw']
loader = MRIDatasetLoader(data_dirs)
df = loader.scan_dataset()
print(f"Scanned {len(df)} image records.")
df.head()
